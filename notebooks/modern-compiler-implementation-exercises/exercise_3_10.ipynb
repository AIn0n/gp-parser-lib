# %%
from IPython.core.display import SVG

from parsers.lr.lr1 import LR1Parser
from parsers.lr.to_graphviz import lr_parser_to_graphviz

# %% [markdown]
# ## Exercise 3.10
#
# Diagram the LR(1) states for the grammar of Exercise 3.7 (without left-factoring),
# and construct the LR(1) parsing table. Indicate clearly any conflicts.

# %%
grammar_ex_3_7 = ["S -> G $", "G -> P", "G -> P G", "P -> id : R", "R -> id R", "R -> "]

parser = LR1Parser(*grammar_ex_3_7)

# %%
SVG(lr_parser_to_graphviz(parser).create_svg())

# %%
print(parser.to_tabulate())

# %%
parser.print_rules_and_states()

# %% [markdown]
# Parser in state 4 and 8 didn't know, if it should reduce using empty rule, or go further and parse the whole R symbol.
