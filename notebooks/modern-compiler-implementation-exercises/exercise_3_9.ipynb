# %% [markdown]
# # Exercise 3.9
#
# Diagram the LR(0) states for Grammar 3.26, build the SLR parsing table, and
# identify the conflicts.
#
# ## LR(0) states

# %%
from IPython.core.display import SVG

from parsers.lr.lr0 import LR0Parser
from parsers.lr.slr import SLRParser

from parsers.example_grammars import GRAMMAR_3_26
from parsers.lr.to_graphviz import lr_parser_to_graphviz

# %%
p = LR0Parser()
p.add_rules(*GRAMMAR_3_26)
p.compute_states_and_edges()

# %%
dot = lr_parser_to_graphviz(p, title="Grammar 3.26")

# %%
SVG(dot.create_svg())

# %% [markdown]
# ## Parsing table
#
# Using SLR parser

# %%
slr = SLRParser()
slr.add_rules(*GRAMMAR_3_26)
print(slr.to_tabulate())

# %%
p.print_rules_and_states()

# %% [markdown]
# Conflicts happen in state 6, with symbol `=` as an input. Compiler didn't know if
# it should reduce V to E rule or just to go further, and shift the dot after `=` symbol.
