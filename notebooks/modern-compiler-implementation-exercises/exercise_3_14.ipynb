# %% [markdown]
# # Exercise 3.14
#
# Show that given grammar is LL(1) but not LALR(1)

# %%
grammar = [
    "S -> ( X",
    "S -> E ]",
    "S -> F )",
    "X -> E )",
    "X -> F ]",
    "E -> A",
    "F -> A",
    "A ->",
]

# %%
from parsers.lr.lr1 import LR1Parser
from parsers.ll import LL1Parser

# %% [markdown]
# ### Using LR(1) and LALR(1)

# %%
lr1 = LR1Parser(*grammar)
lr1.parsing_table
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 lr1 = LR1Parser(*grammar)
#       2 lr1.parsing_table
#
# File ~/git/modern-compiler-impl/py-exercises/src/parsers/lr/lr1.py:21, in LR1Parser.__init__(self, styling, end_symbol, *rules)
#      15 def __init__(
#      16     self,
#      17     *rules: str,
#      18     styling: ParserPrintStyler | None = None,
#      19     end_symbol: str = "$",
#      20 ):
# ---> 21     super().__init__(*rules, styling=styling, end_symbol=end_symbol)
#
# File ~/git/modern-compiler-impl/py-exercises/src/parsers/lr/lr0.py:29, in LR0Parser.__init__(self, styling, end_symbol, *rules)
#      27 self.states: dict[int, LRState] = dict()
#      28 self.edges: set[IndexedLREdge] = set()
# ---> 29 self.compute_states_and_edges()
#
# ...

# %%
ll = LL1Parser(*grammar)
print(ll.to_tabulate())
# Out:
# ┌────┬──────────┬──────────┬──────────┐
# │    │ (        │ )        │ ]        │
# ├────┼──────────┼──────────┼──────────┤
# │ A  │          │ A -> ε   │ A -> ε   │
# ├────┼──────────┼──────────┼──────────┤
# │ E  │          │ E -> A   │ E -> A   │
# ├────┼──────────┼──────────┼──────────┤
# │ F  │          │ F -> A   │ F -> A   │
# ├────┼──────────┼──────────┼──────────┤
# │ S  │ S -> ( X │ S -> F ) │ S -> E ] │
# ├────┼──────────┼──────────┼──────────┤
# │ X  │          │ X -> E ) │ X -> F ] │
# └────┴──────────┴──────────┴──────────┘
